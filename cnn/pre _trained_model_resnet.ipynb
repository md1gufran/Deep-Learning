# %%
from PIL import Image
image = Image.open('cat.jfif')
import numpy as np

# %%
type(image)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
def normalize_to_minus_one_to_one(arr):
  min_val = np.min(arr)
  max_val = np.max(arr)
  normalized_arr = 2*(arr - min_val)/(max_val - min_val)-1
  return normalized_arr

# %%
normalized_image_2 = np.true_divide(image, 255, dtype=np.float32)

# %%
normalized_arr = normalize_to_minus_one_to_one(normalized_image_2)

# %%
normalized_image_2
# Out:
# array([[[0.16078432, 0.14117648, 0.1254902 ],
#         [0.16078432, 0.14117648, 0.1254902 ],
#         [0.16078432, 0.14117648, 0.1254902 ],
#         ...,
#         [0.8352941 , 0.76862746, 0.6901961 ],
#         [0.8352941 , 0.76862746, 0.6901961 ],
#         [0.8352941 , 0.76862746, 0.6901961 ]],
#
#        [[0.16078432, 0.14117648, 0.1254902 ],
#         [0.16078432, 0.14117648, 0.1254902 ],
#         [0.16078432, 0.14117648, 0.1254902 ],
#         ...,
#         [0.8352941 , 0.76862746, 0.6901961 ],
#         [0.8352941 , 0.76862746, 0.6901961 ],
#         [0.8352941 , 0.76862746, 0.6901961 ]],
#
#        [[0.16078432, 0.14117648, 0.1254902 ],
#         [0.16078432, 0.14117648, 0.1254902 ],
#         [0.16078432, 0.14117648, 0.1254902 ],
#         ...,
#         [0.8352941 , 0.76862746, 0.6901961 ],
#         [0.8352941 , 0.76862746, 0.6901961 ],
#         [0.8352941 , 0.76862746, 0.6901961 ]],
#
#        ...,
#
#        [[0.04705882, 0.05098039, 0.12156863],
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(normalized_image_2)

# %% [markdown]
# Using Pre-Trained Model From keras.application,resnet50

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input,decode_predictions
import numpy as np

# %%
model = ResNet50(weights = 'imagenet')
# Out:
# ...
# 102967424/102967424 [==============================] - 0s 0us/step

# %%
img_path = '/content/tomato.jfif'
img = image.load_img(img_path,target_size=(224,224))
x = image.img_to_array(img)
x = np.expand_dims(x,axis=0)
x = preprocess_input(x)

# %%
pred = model.predict(x)
print('Predicted',decode_predictions(pred,top=3)[0])
# Out:
# ...
# 35363/35363 [==============================] - 0s 0us/step
# Predicted [('n12620546', 'hip', 0.37022385), ('n07768694', 'pomegranate', 0.18874395), ('n07720875', 'bell_pepper', 0.11540508)]
